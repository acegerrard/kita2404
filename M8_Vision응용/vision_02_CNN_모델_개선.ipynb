# %% [markdown]
# ## 모델 개선
# - 과대적합 방지 - 학습 파라미터 수 축소
# - 모델 성능 높이기 - 레이어 추가
# - 모델 성능 높이기 - 이미지 증식

# %% [markdown]
# - SpatialDropout2D: 2D 공간에서 특정 뉴런을 무작위로 드롭아웃합니다.
# - ReduceLROnPlateau: 학습 성능이 개선되지 않을 경우 학습률을 동적으로 감소시킵니다.
# - ImageDataGenerator: 이미지 데이터를 실시간으로 증강(augmentation)시키는 클래스입니다. 데이터 양을 늘리고 과적합을 방지하기 위해 이미지 회전, 확대, 축소 등의 변환을 수행할 수 있습니다.

# %%
import datetime
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-white')

from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout, SpatialDropout2D, Flatten, Conv2D, MaxPooling2D, Reshape, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

# 데이터 로드
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# 이미지 데이터에 채널 차원이 명시적으로 없는 경우 (예: (28, 28) 크기의 이미지) 채널 차원을 추가
x_train = x_train[..., np.newaxis] # (28, 28) -> (28, 28, 1)
x_test = x_test[..., np.newaxis]

# 이미지 데이터 정규화 (픽셀 값을 0~1 범위로 변환)

x_train = x_train / 255.0
x_test = x_test / 255.0

# 데이터 셰이프 출력
print(x_train.shape)  # (60000, 28, 28, 1)
print(y_train.shape)  # (60000,)
print(x_test.shape)   # (10000, 28, 28, -1)
print(y_test.shape)   # (10000,)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# (60000, 28, 28, 1)
# (60000,)
# (10000, 28, 28, 1)
# (10000,)

# %%
class_names = ['T-Shirt','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle Boot']

# %%
# 모델 구성 및 컴파일+

def build_model():
    # model=Sequential()
    input = Input(shape=(28, 28, 1))
    output = Conv2D(filters=32, kernel_size=(3,3))(input) # kernel 수 : 32개
    output = Conv2D(filters=64, kernel_size=(3,3))(output)
    output = Conv2D(filters=64, kernel_size=(3,3))(output)
    output = Flatten()(output) # 완전연결층
    output = Dense(128, activation='relu')(output) # 활성화 함수 : relu
    output = Dense(64, activation='relu')(output)
    output = Dense(10, activation='softmax')(output)

    model = Model(inputs=[input], outputs=output)  # 모델이 하나 이상의 입력을 받을 수 있으며 출력은 단일 출력을 함

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy']) # loss: 손실함수
    return model

model_1 = build_model()
model_1.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 24, 24, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 22, 22, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 30976)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       3,965,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,029,706 (15.37 MB)
#  Trainable params: 4,029,706 (15.37 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint


# modelcheckpoint 콜백 설정
model_checkpoint = ModelCheckpoint(
    'best_model.keras', # 모델 파일 경로
    monitor='val_loss', # 모니터링 대상 성능 지표
    verbose=1, # 로그를 입력
    save_best_only=True, # 가장 좋은 모델만 저장
)

# EerlyStopping 콜백 설정
early_stopping = EarlyStopping(
    monitor='val_loss', # 모니터링 대상 성능 지표
    patience=5, # 성능 개선이 없는 에폭을 몇 번까지 허용할지 설정
    verbose=1, # 로그를 출력
)

# 학습 실행
hist_1 = model_1.fit(
    x_train, y_train,
    epochs=40,
    batch_size=128,
    validation_split=0.3,
    callbacks=[model_checkpoint, early_stopping], # 콜백 리스트에 추가
)
# Out:
# Epoch 1/40
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7531 - loss: 0.6912
# Epoch 1: val_loss improved from inf to 0.39546, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.7533 - loss: 0.6907 - val_accuracy: 0.8597 - val_loss: 0.3955
# Epoch 2/40
# 325/329 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8718 - loss: 0.3486
# Epoch 2: val_loss improved from 0.39546 to 0.36013, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8719 - loss: 0.3485 - val_accuracy: 0.8708 - val_loss: 0.3601
# Epoch 3/40
# 324/329 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8961 - loss: 0.2836
# Epoch 3: val_loss improved from 0.36013 to 0.35779, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8961 - loss: 0.2836 - val_accuracy: 0.8734 - val_loss: 0.3578
# Epoch 4/40
# 324/329 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9099 - loss: 0.2398
# Epoch 4: val_loss did not improve from 0.35779
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9099 - loss: 0.2399 - val_accuracy: 0.8712 - val_loss: 0.3784
# Epoch 5/40
# 325/329 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9310 - loss: 0.1865
# Epoch 5: val_loss did not improve from 0.35779
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9309 - loss: 0.1867 - val_accuracy: 0.8741 - val_loss: 0.3973
# Epoch 6/40
# 324/329 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9374 - loss: 0.1682
# Epoch 6: val_loss did not improve from 0.35779
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9373 - loss: 0.1685 - val_accuracy: 0.8662 - val_loss: 0.4248
# Epoch 7/40
# 324/329 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9436 - loss: 0.1488
# Epoch 7: val_loss did not improve from 0.35779
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9436 - loss: 0.1490 - val_accuracy: 0.8706 - val_loss: 0.4676
# Epoch 8/40
# 325/329 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9544 - loss: 0.1237
# Epoch 8: val_loss did not improve from 0.35779
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9543 - loss: 0.1239 - val_accuracy: 0.8698 - val_loss: 0.5085
# Epoch 8: early stopping

# %%
import matplotlib.pyplot as plt

hist_1.history.keys()
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(hist_1.history['loss'],'b--',label='loss')
plt.plot(hist_1.history['val_loss'],'r',label='val_loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend()

plt.subplot(1,2,2)
plt.plot(hist_1.history['accuracy'],'b--',label='accuracy')
plt.plot(hist_1.history['val_accuracy'],'r',label='val_accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend()
plt.show()

# %%
model_1.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8599 - loss: 0.5792
# [0.5617450475692749, 0.8615999817848206]

# %% [markdown]
# ### 모델 구성 및 학습: 과대적합 방지
#
# - 학습 파라미터의 수 비교
#   - 모델 1은 더 많은 Conv2D 레이어를 포함하고 있으며, MaxPooling2D 및 Dropout 레이어가 없으므로 학습할 파라미터가 더 많습니다.
#   - 모델 2는 Conv2D 레이어 후 MaxPooling2D와 Dropout 레이어를 추가하여 파라미터 수를 줄이는 동시에, 과적합을 방지하는 데 더 신경 쓴 모델입니다.

# %%
# 슬림한 모델로 바꾼 결과 과적합은 방지하지만 성능은 좋지 않음
def build_model2():

    input = Input(shape=(28,28,1))
    output = Conv2D(filters=32,kernel_size=(3,3))(input)
    output = MaxPooling2D(strides=(2,2))(output)
    output = Conv2D(filters=64,kernel_size=(3,3))(output)
    output = Dropout(0.4)(output)
    output = MaxPooling2D(strides=(2,2))(output)
    output = Conv2D(filters=64,kernel_size=(3,3))(output)
    output = Dropout(0.4)(output)
    output = MaxPooling2D(strides=(2,2))(output)
    output = Flatten()(output)
    output = Dense(128,activation='relu')(output)
    output = Dropout(0.5)(output)
    output = Dense(64,activation='relu')(output)
    output = Dropout(0.5)(output)
    output = Dense(10,activation='softmax')(output)

    model = Model(inputs=[input], outputs=output)

    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

model_2 = build_model2()
model_2.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 11, 11, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 11, 11, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 3, 3, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 3, 3, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 1, 1, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 72,970 (285.04 KB)
#  Trainable params: 72,970 (285.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint


# modelcheckpoint 콜백 설정
model_checkpoint = ModelCheckpoint(
    'best_model.keras', # 모델 파일 경로
    monitor='val_loss', # 모니터링 대상 성능 지표
    verbose=1, # 로그를 입력
    save_best_only=True, # 가장 좋은 모델만 저장
)

# EerlyStopping 콜백 설정
early_stopping = EarlyStopping(
    monitor='val_loss', # 모니터링 대상 성능 지표
    patience=5, # 성능 개선이 없는 에폭을 몇 번까지 허용할지 설정
    verbose=1, # 로그를 출력
)

# 학습 실행
hist_2 = model_2.fit(
    x_train, y_train,
    epochs=40,
    batch_size=128,
    validation_split=0.3,
    callbacks=[model_checkpoint, early_stopping], # 콜백 리스트에 추가
)
# Out:
# Epoch 1/40
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4305 - loss: 1.5314
# Epoch 1: val_loss improved from inf to 0.67366, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - accuracy: 0.4310 - loss: 1.5302 - val_accuracy: 0.7577 - val_loss: 0.6737
# Epoch 2/40
# 315/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7228 - loss: 0.7539
# Epoch 2: val_loss improved from 0.67366 to 0.59215, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7233 - loss: 0.7526 - val_accuracy: 0.7802 - val_loss: 0.5922
# Epoch 3/40
# 317/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7646 - loss: 0.6609
# Epoch 3: val_loss improved from 0.59215 to 0.54401, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7648 - loss: 0.6601 - val_accuracy: 0.7972 - val_loss: 0.5440
# Epoch 4/40
# 315/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7867 - loss: 0.6018
# Epoch 4: val_loss improved from 0.54401 to 0.51797, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7867 - loss: 0.6018 - val_accuracy: 0.8100 - val_loss: 0.5180
# Epoch 5/40
# 323/329 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7934 - loss: 0.5832
# Epoch 5: val_loss improved from 0.51797 to 0.50691, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7935 - loss: 0.5829 - val_accuracy: 0.8131 - val_loss: 0.5069
# Epoch 6/40
# 326/329 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8036 - loss: 0.5561
# Epoch 6: val_loss improved from 0.50691 to 0.47859, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8036 - loss: 0.5560 - val_accuracy: 0.8215 - val_loss: 0.4786
# Epoch 7/40
# 317/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8128 - loss: 0.5336
# Epoch 7: val_loss did not improve from 0.47859
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8127 - loss: 0.5336 - val_accuracy: 0.8225 - val_loss: 0.4822
# Epoch 8/40
# 316/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8199 - loss: 0.5074
# Epoch 8: val_loss did not improve from 0.47859
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8199 - loss: 0.5075 - val_accuracy: 0.8204 - val_loss: 0.4853
# Epoch 9/40
# 317/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8239 - loss: 0.4999
# Epoch 9: val_loss did not improve from 0.47859
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8239 - loss: 0.4999 - val_accuracy: 0.8167 - val_loss: 0.4985
# Epoch 10/40
# 319/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8259 - loss: 0.4891
# Epoch 10: val_loss improved from 0.47859 to 0.43960, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8259 - loss: 0.4891 - val_accuracy: 0.8422 - val_loss: 0.4396
# Epoch 11/40
# 323/329 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8308 - loss: 0.4827
# Epoch 11: val_loss did not improve from 0.43960
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8309 - loss: 0.4825 - val_accuracy: 0.8401 - val_loss: 0.4510
# Epoch 12/40
# 326/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8354 - loss: 0.4734
# Epoch 12: val_loss did not improve from 0.43960
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8354 - loss: 0.4734 - val_accuracy: 0.8387 - val_loss: 0.4414
# Epoch 13/40
# 315/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8415 - loss: 0.4641
# Epoch 13: val_loss improved from 0.43960 to 0.42149, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8416 - loss: 0.4638 - val_accuracy: 0.8502 - val_loss: 0.4215
# Epoch 14/40
# 316/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8497 - loss: 0.4386
# Epoch 14: val_loss improved from 0.42149 to 0.41257, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8495 - loss: 0.4391 - val_accuracy: 0.8529 - val_loss: 0.4126
# Epoch 15/40
# 314/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8491 - loss: 0.4333
# Epoch 15: val_loss did not improve from 0.41257
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8491 - loss: 0.4335 - val_accuracy: 0.8494 - val_loss: 0.4197
# Epoch 16/40
# 318/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8507 - loss: 0.4311
# Epoch 16: val_loss improved from 0.41257 to 0.41018, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8507 - loss: 0.4312 - val_accuracy: 0.8532 - val_loss: 0.4102
# Epoch 17/40
# 327/329 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8522 - loss: 0.4308
# Epoch 17: val_loss improved from 0.41018 to 0.39922, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8522 - loss: 0.4308 - val_accuracy: 0.8586 - val_loss: 0.3992
# Epoch 18/40
# 328/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8522 - loss: 0.4254
# Epoch 18: val_loss did not improve from 0.39922
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8522 - loss: 0.4254 - val_accuracy: 0.8451 - val_loss: 0.4137
# Epoch 19/40
# 323/329 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8567 - loss: 0.4178
# Epoch 19: val_loss did not improve from 0.39922
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8567 - loss: 0.4179 - val_accuracy: 0.8560 - val_loss: 0.4084
# Epoch 20/40
# 314/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8578 - loss: 0.4124
# Epoch 20: val_loss did not improve from 0.39922
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8577 - loss: 0.4126 - val_accuracy: 0.8559 - val_loss: 0.4025
# Epoch 21/40
# 314/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8597 - loss: 0.4093
# Epoch 21: val_loss did not improve from 0.39922
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8596 - loss: 0.4094 - val_accuracy: 0.8551 - val_loss: 0.4045
# Epoch 22/40
# 328/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8582 - loss: 0.4088
# Epoch 22: val_loss improved from 0.39922 to 0.38712, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8582 - loss: 0.4088 - val_accuracy: 0.8604 - val_loss: 0.3871
# Epoch 23/40
# 315/329 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8618 - loss: 0.4037
# Epoch 23: val_loss did not improve from 0.38712
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8618 - loss: 0.4037 - val_accuracy: 0.8567 - val_loss: 0.4054
# Epoch 24/40
# 317/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8614 - loss: 0.3948
# Epoch 24: val_loss improved from 0.38712 to 0.38466, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8614 - loss: 0.3951 - val_accuracy: 0.8623 - val_loss: 0.3847
# Epoch 25/40
# 318/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8616 - loss: 0.4003
# Epoch 25: val_loss did not improve from 0.38466
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8617 - loss: 0.4003 - val_accuracy: 0.8536 - val_loss: 0.4133
# Epoch 26/40
# 314/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8607 - loss: 0.4054
# Epoch 26: val_loss improved from 0.38466 to 0.36636, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8608 - loss: 0.4054 - val_accuracy: 0.8668 - val_loss: 0.3664
# Epoch 27/40
# 319/329 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8683 - loss: 0.3876
# Epoch 27: val_loss did not improve from 0.36636
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8683 - loss: 0.3878 - val_accuracy: 0.8604 - val_loss: 0.3950
# Epoch 28/40
# 322/329 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8640 - loss: 0.3901
# Epoch 28: val_loss did not improve from 0.36636
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8641 - loss: 0.3901 - val_accuracy: 0.8556 - val_loss: 0.4051
# Epoch 29/40
# 316/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8662 - loss: 0.3951
# Epoch 29: val_loss did not improve from 0.36636
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8663 - loss: 0.3950 - val_accuracy: 0.8646 - val_loss: 0.3783
# Epoch 30/40
# 314/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8644 - loss: 0.3959
# Epoch 30: val_loss did not improve from 0.36636
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8645 - loss: 0.3955 - val_accuracy: 0.8633 - val_loss: 0.3834
# Epoch 31/40
# 328/329 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8668 - loss: 0.3850
# Epoch 31: val_loss did not improve from 0.36636
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8668 - loss: 0.3850 - val_accuracy: 0.8547 - val_loss: 0.3983
# Epoch 31: early stopping

# %%
import matplotlib.pyplot as plt

hist_2.history.keys()
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(hist_2.history['loss'],'b--',label='loss')
plt.plot(hist_2.history['val_loss'],'r',label='val_loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend()

plt.subplot(1,2,2)
plt.plot(hist_2.history['accuracy'],'b--',label='accuracy')
plt.plot(hist_2.history['val_accuracy'],'r',label='val_accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend()
plt.show()

# %%
model_2.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8497 - loss: 0.4179
# [0.413179486989975, 0.8486999869346619]

# %% [markdown]
# ### 모델 성능 높이기: 레이어 추가
#
# padding='same'과 'valid'옵션을 코드 내에서 별도로 설정하는 이유
# - 모델 설계자가 네트워크의 각 계층에서 출력의 크기와 특성 추출 방식을 세밀하게 제어하고자 하는 것이다.
# - 아래 경우에는 초기에는 공간 차원을 유지하면서 입력 데이터의 전반적인 특성을 포착하고 네트워크가 깊어질 수록 더 추상화된 특성을 추출하려는 목적으로 생각해 볼 수 있음.

# %%
def build_model3():

    input = Input(shape=(28,28,1))
    output = Conv2D(filters=32,kernel_size=3, activation='relu', padding='same')(input)
    output = BatchNormalization()(output)
    output = Conv2D(filters=64,kernel_size=3, activation='relu', padding='valid')(output)
    output = Dropout(0.5)(output)
    output = MaxPooling2D(strides=(2,2))(output)

    output = Conv2D(filters=128,kernel_size=3, activation='relu', padding='same')(output)
    output = BatchNormalization()(output)
    output = Conv2D(filters=128,kernel_size=3, activation='relu', padding='valid')(output)
    output = Dropout(0.5)(output)
    output = MaxPooling2D(strides=(2,2))(output)

    output = Conv2D(filters=256,kernel_size=3, activation='relu', padding='same')(output)
    output = BatchNormalization()(output)
    output = Conv2D(filters=256,kernel_size=3, activation='relu', padding='valid')(output)
    output = Dropout(0.5)(output)
    output = MaxPooling2D(strides=(2,2))(output)

    output = Flatten()(output)
    output = Dense(512,activation='relu')(output)
    output = Dropout(0.5)(output)
    output = Dense(256,activation='relu')(output)
    output = Dropout(0.5)(output)
    output = Dense(10,activation='softmax')(output)

    model = Model(inputs=[input], outputs=output)

    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

model_3 = build_model3()
model_3.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)           │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 28, 28, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 26, 26, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 26, 26, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 13, 13, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_14 (Conv2D)                   │ (None, 13, 13, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 13, 13, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_15 (Conv2D)                   │ (None, 11, 11, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 11, 11, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 5, 5, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_16 (Conv2D)                   │ (None, 5, 5, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 5, 5, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_17 (Conv2D)                   │ (None, 3, 3, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 3, 3, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_15 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_16 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,392,650 (5.31 MB)
#  Trainable params: 1,391,818 (5.31 MB)
#  Non-trainable params: 832 (3.25 KB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint


# modelcheckpoint 콜백 설정
model_checkpoint = ModelCheckpoint(
    'best_model.keras', # 모델 파일 경로
    monitor='val_loss', # 모니터링 대상 성능 지표
    verbose=1, # 로그를 입력
    save_best_only=True, # 가장 좋은 모델만 저장
)

# EerlyStopping 콜백 설정
early_stopping = EarlyStopping(
    monitor='val_loss', # 모니터링 대상 성능 지표
    patience=5, # 성능 개선이 없는 에폭을 몇 번까지 허용할지 설정
    verbose=1, # 로그를 출력
)

# 학습 실행
hist_3 = model_3.fit(
    x_train, y_train,
    epochs=40,
    batch_size=128,
    validation_split=0.3,
    callbacks=[model_checkpoint, early_stopping], # 콜백 리스트에 추가
)
# Out:
# Epoch 1/40
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6200 - loss: 1.1131
# Epoch 1: val_loss improved from inf to 2.11930, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 29s 55ms/step - accuracy: 0.6204 - loss: 1.1120 - val_accuracy: 0.2586 - val_loss: 2.1193
# Epoch 2/40
# 328/329 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8284 - loss: 0.4788
# Epoch 2: val_loss improved from 2.11930 to 1.05430, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.8285 - loss: 0.4786 - val_accuracy: 0.6387 - val_loss: 1.0543
# Epoch 3/40
# 328/329 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8683 - loss: 0.3807
# Epoch 3: val_loss improved from 1.05430 to 0.61163, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8683 - loss: 0.3806 - val_accuracy: 0.8388 - val_loss: 0.6116
# Epoch 4/40
# 326/329 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8787 - loss: 0.3519
# Epoch 4: val_loss did not improve from 0.61163
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.8788 - loss: 0.3518 - val_accuracy: 0.7484 - val_loss: 0.7154
# Epoch 5/40
# 327/329 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8939 - loss: 0.3107
# Epoch 5: val_loss improved from 0.61163 to 0.53838, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.8939 - loss: 0.3107 - val_accuracy: 0.8144 - val_loss: 0.5384
# Epoch 6/40
# 327/329 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8989 - loss: 0.2884
# Epoch 6: val_loss improved from 0.53838 to 0.48318, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8989 - loss: 0.2884 - val_accuracy: 0.8724 - val_loss: 0.4832
# Epoch 7/40
# 328/329 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9050 - loss: 0.2694
# Epoch 7: val_loss did not improve from 0.48318
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9050 - loss: 0.2694 - val_accuracy: 0.8169 - val_loss: 0.5641
# Epoch 8/40
# 328/329 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9124 - loss: 0.2543
# Epoch 8: val_loss improved from 0.48318 to 0.45067, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.9124 - loss: 0.2543 - val_accuracy: 0.8649 - val_loss: 0.4507
# Epoch 9/40
# 328/329 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9115 - loss: 0.2566
# Epoch 9: val_loss improved from 0.45067 to 0.43643, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9115 - loss: 0.2565 - val_accuracy: 0.8701 - val_loss: 0.4364
# Epoch 10/40
# 328/329 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9154 - loss: 0.2419
# Epoch 10: val_loss improved from 0.43643 to 0.37069, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.9154 - loss: 0.2420 - val_accuracy: 0.8823 - val_loss: 0.3707
# Epoch 11/40
# 327/329 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9190 - loss: 0.2331
# Epoch 11: val_loss did not improve from 0.37069
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9190 - loss: 0.2331 - val_accuracy: 0.8612 - val_loss: 0.4235
# Epoch 12/40
# 327/329 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9193 - loss: 0.2259
# Epoch 12: val_loss did not improve from 0.37069
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.9193 - loss: 0.2260 - val_accuracy: 0.8445 - val_loss: 0.4969
# Epoch 13/40
# 326/329 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9250 - loss: 0.2133
# Epoch 13: val_loss improved from 0.37069 to 0.33454, saving model to best_model.keras
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9250 - loss: 0.2134 - val_accuracy: 0.8973 - val_loss: 0.3345
# Epoch 14/40
# 327/329 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9240 - loss: 0.2140
# Epoch 14: val_loss did not improve from 0.33454
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9241 - loss: 0.2140 - val_accuracy: 0.8984 - val_loss: 0.3743
# Epoch 15/40
# 327/329 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9242 - loss: 0.2085
# Epoch 15: val_loss did not improve from 0.33454
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9242 - loss: 0.2085 - val_accuracy: 0.8828 - val_loss: 0.3593
# Epoch 16/40
# 327/329 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9307 - loss: 0.1949
# Epoch 16: val_loss did not improve from 0.33454
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9306 - loss: 0.1949 - val_accuracy: 0.8984 - val_loss: 0.3827
# Epoch 17/40
# 326/329 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9307 - loss: 0.1959
# Epoch 17: val_loss did not improve from 0.33454
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9306 - loss: 0.1959 - val_accuracy: 0.8954 - val_loss: 0.3732
# Epoch 18/40
# 328/329 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9329 - loss: 0.1944
# Epoch 18: val_loss did not improve from 0.33454
# 329/329 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.9329 - loss: 0.1944 - val_accuracy: 0.8632 - val_loss: 0.4309
# Epoch 18: early stopping

# %%
import matplotlib.pyplot as plt

hist_3.history.keys()
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(hist_3.history['loss'],'b--',label='loss')
plt.plot(hist_3.history['val_loss'],'r',label='val_loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend()

plt.subplot(1,2,2)
plt.plot(hist_3.history['accuracy'],'b--',label='accuracy')
plt.plot(hist_3.history['val_accuracy'],'r',label='val_accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend()
plt.show()

# %%
model_3.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8636 - loss: 0.4413
# [0.4341968894004822, 0.8652999997138977]

# %% [markdown]
# ### CNN(Convolutional Neural Network)에서 파라미터 수의 증가 요소
#
# - 필터(커널)의 수: CNN의 각 합성곱 계층(Convolutional layer)은 여러 필터(또는 커널)를 사용하여 입력 이미지에서 특징을 추출합니다. 필터의 수가 많아질수록 더 많은 특징을 동시에 학습할 수 있지만, 이는 동시에 해당 계층의 파라미터 수를 증가시킵니다.
#
# - 필터의 크기: 필터의 크기가 클수록 한 번에 더 넓은 영역의 정보를 처리할 수 있습니다. 그러나 필터 크기의 증가는 필터 내의 가중치 수를 증가시켜, 결과적으로 해당 계층의 전체 파라미터 수를 증가시킵니다.
#
# - 완전연결계층(Fully Connected layers)의 크기: CNN의 끝부분에서 주로 사용되는 전결합 계층은 모든 입력을 각 출력 뉴런에 연결합니다. 이 계층의 뉴런(유닛) 수가 많을수록 모델의 파라미터 수가 크게 증가합니다. 전결합 계층은 일반적으로 모델 내에서 가장 많은 파라미터를 가집니다.
#
# - 계층의 깊이: CNN의 계층(레이어) 수가 많아질수록, 즉 모델이 더 깊어질수록, 모델이 더 복잡한 특징을 학습할 수 있게 되지만, 이는 또한 전체 파라미터 수를 증가시킵니다.
#
# - 특성 맵(Feature Map)의 크기: 특정 합성곱 계층이 출력하는 특성 맵의 크기가 크면 클수록, 그 다음 계층(특히 전결합 계층이나 합성곱 계층)의 파라미터 수가 증가할 수 있습니다. 특성 맵의 크기는 입력 이미지의 크기와 필터의 크기, 스트라이드(stride), 패딩(padding)에 의해 결정됩니다.
#
# 이러한 요소들은 모두 모델의 학습 능력과 일반화 능력에 영향을 미칩니다. 파라미터 수가 많은 모델은 더 복잡한 특징을 학습할 수 있지만, 과적합(overfitting)의 위험도 높아질 수 있습니다. 반면, 파라미터 수가 적은 모델은 계산 효율성은 높지만, 모델의 표현 능력이 제한될 수 있습니다. 따라서 모델 설계 시 이러한 점을 고려하여 적절한 균형을 찾는 것이 중요합니다.

# %% [markdown]
# ### 모델 성능 높이기: 이미지 증강(Image Augmentation)
# 데이터 증강은 기존의 훈련 데이터를 다양하게 변형하여 모델의 일반화 능력을 향상시키는 기법입니다. 각 파라미터는 특정 방식으로 이미지를 변형합니다.
#
# ImageDataGenerator 파라미터 설명:
# - rotation_range=10: 이미지를 -10도에서 10도 사이로 무작위로 회전합니다.
# - zoom_range=0.2: 이미지를 80%에서 120% 사이로 무작위로 확대/축소합니다.
# - shear_range=0.6: 이미지를 반시계 방향으로 0.6 라디안 내에서 기울입니다.
# - width_shift_range=0.1와 height_shift_range=0.1: 각각 이미지를 수평과 수직으로 최대 10% 내에서 무작위로 이동합니다.
# - horizontal_flip=True: 수평 방향으로 이미지를 무작위로 뒤집습니다. (예: 좌우 반전)
# - vertical_flip=False: 수직 방향으로 이미지를 뒤집지 않습니다.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_generator = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.2,
    shear_range=0.6,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False
)
augment_size = 200 # 데이터 증강을 통해 생성하고자 하는 증강된 이미지의 수
print(x_train.shape)
print(x_train[0].shape)
# Out:
# (60000, 28, 28, 1)
# (28, 28, 1)

# %%
# flow 메소드는 실제로 이미지 데이터를 변환하는 작업을 수행
# np.tile(x_train[0],reshape(28*28*1),augument_size.reshape(-1,28,28,1)은 첫번째 훈련 이미지(x_train[0])을 augument_size(200)만큼 복제하여 증강된 이미지 데이터의 형태로 변환)
# np.zeros(augument_size)는 증강된 이미지에 대한 레이블을 생성
# batch_size=augment_size는 한번에 생성할 증강된 이미지의 수를 지정
# next()[0]을 통해 생성된 이미지 배치 중 첫 번째 배치(즉, 증강된 이미지들)에 접근
# 이미지 증강

x_augment_iterator = image_generator.flow(
    np.repeat(x_train[0].reshape(1, 28, 28, 1), augment_size, axis=0), # 이미지 복제 후 증강
    np.zeros(augment_size), # 라벨은 필요하지 않으므로 0으로 채움
    batch_size=augment_size,
    shuffle=False
)

# 첫 번째 배치 가져오기
x_augment = next(x_augment_iterator)[0]

print(x_augment.shape) # 증강된 이미지의 형상을 확인
# Out:
# (200, 28, 28, 1)

# %%
plt.figure(figsize=(10,10))
for i in range(1,101):
    plt.subplot(10,10,i)
    plt.axis('off')
    plt.imshow(x_augment[i-1].reshape(28,28),cmap='gray')

# %%
iamge_generator = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.2,
    shear_range=0.6,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False
)
augment_size = 30000
random_mask = np.random.randint(x_train.shape[0], size = augment_size) # 증강할 이미지들의 인덱스 선정
x_augmented = x_train[random_mask].copy()
y_augmented = y_train[random_mask].copy()

# %%
# 증강할 이미지 생성기 설정
x_augmented = image_generator.flow(
    x_augmented, # 증강할 이미지
    np.zeros(augment_size), # 라벨은 필요하지 않으므로 0으로 채움
    batch_size=augment_size,
    shuffle=False
)

# 첫번쨰 배치 가져오기
x_augmented = next(x_augmented)[0]

# 증강된 이미지의 형상 확인
print(x_augmented.shape)
# Out:
# (30000, 28, 28, 1)

# %%
x_augmented.shape
# Out:
# (30000, 28, 28, 1)

# %%
x_train = np.concatenate((x_train, x_augmented))
y_train = np.concatenate((y_train, y_augmented))
print(x_train.shape)
print(y_train.shape)
# Out:
# (90000, 28, 28, 1)
# (90000,)

# %%
model_4 = build_model3()
model_4.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)           │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_18 (Conv2D)                   │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 28, 28, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_19 (Conv2D)                   │ (None, 26, 26, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_17 (Dropout)                 │ (None, 26, 26, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 13, 13, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_20 (Conv2D)                   │ (None, 13, 13, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 13, 13, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 11, 11, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_18 (Dropout)                 │ (None, 11, 11, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_13 (MaxPooling2D)      │ (None, 5, 5, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_22 (Conv2D)                   │ (None, 5, 5, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 5, 5, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_23 (Conv2D)                   │ (None, 3, 3, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_19 (Dropout)                 │ (None, 3, 3, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_14 (MaxPooling2D)      │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_5 (Flatten)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_20 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_21 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,392,650 (5.31 MB)
#  Trainable params: 1,391,818 (5.31 MB)
#  Non-trainable params: 832 (3.25 KB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint


# modelcheckpoint 콜백 설정
model_checkpoint = ModelCheckpoint(
    'best_model.keras', # 모델 파일 경로
    monitor='val_loss', # 모니터링 대상 성능 지표
    verbose=1, # 로그를 입력
    save_best_only=True, # 가장 좋은 모델만 저장
)

# EerlyStopping 콜백 설정
early_stopping = EarlyStopping(
    monitor='val_loss', # 모니터링 대상 성능 지표
    patience=5, # 성능 개선이 없는 에폭을 몇 번까지 허용할지 설정
    verbose=1, # 로그를 출력
)

# 학습 실행
hist_4 = model_4.fit(
    x_train, y_train,
    epochs=40,
    batch_size=128,
    validation_split=0.3,
    callbacks=[model_checkpoint, early_stopping], # 콜백 리스트에 추가
)
# Out:
# Epoch 1/40
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6412 - loss: 1.0331
# Epoch 1: val_loss improved from inf to 2.05392, saving model to best_model.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 31s 48ms/step - accuracy: 0.6414 - loss: 1.0324 - val_accuracy: 0.1833 - val_loss: 2.0539
# Epoch 2/40
# 490/493 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8493 - loss: 0.4304
# Epoch 2: val_loss improved from 2.05392 to 1.17931, saving model to best_model.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.8493 - loss: 0.4303 - val_accuracy: 0.6847 - val_loss: 1.1793
# Epoch 3/40
# 492/493 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8758 - loss: 0.3567
# Epoch 3: val_loss improved from 1.17931 to 1.09902, saving model to best_model.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8758 - loss: 0.3567 - val_accuracy: 0.6716 - val_loss: 1.0990
# Epoch 4/40
# 491/493 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8861 - loss: 0.3188
# Epoch 4: val_loss improved from 1.09902 to 0.99146, saving model to best_model.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8861 - loss: 0.3188 - val_accuracy: 0.7300 - val_loss: 0.9915
# Epoch 5/40
# 491/493 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8974 - loss: 0.2940
# Epoch 5: val_loss improved from 0.99146 to 0.93135, saving model to best_model.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8974 - loss: 0.2940 - val_accuracy: 0.7571 - val_loss: 0.9314
# Epoch 6/40
# 491/493 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9015 - loss: 0.2832
# Epoch 6: val_loss did not improve from 0.93135
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9015 - loss: 0.2831 - val_accuracy: 0.7325 - val_loss: 0.9425
# Epoch 7/40
# 491/493 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9076 - loss: 0.2698
# Epoch 7: val_loss did not improve from 0.93135
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9076 - loss: 0.2698 - val_accuracy: 0.7596 - val_loss: 0.9980
# Epoch 8/40
# 491/493 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9116 - loss: 0.2505
# Epoch 8: val_loss did not improve from 0.93135
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9116 - loss: 0.2505 - val_accuracy: 0.6408 - val_loss: 0.9719
# Epoch 9/40
# 490/493 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9144 - loss: 0.2450
# Epoch 9: val_loss did not improve from 0.93135
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9144 - loss: 0.2450 - val_accuracy: 0.6145 - val_loss: 1.2784
# Epoch 10/40
# 491/493 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9188 - loss: 0.2341
# Epoch 10: val_loss improved from 0.93135 to 0.87316, saving model to best_model.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9187 - loss: 0.2342 - val_accuracy: 0.7267 - val_loss: 0.8732
# Epoch 11/40
# 491/493 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9212 - loss: 0.2199
# Epoch 11: val_loss improved from 0.87316 to 0.80666, saving model to best_model.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.9212 - loss: 0.2199 - val_accuracy: 0.7953 - val_loss: 0.8067
# Epoch 12/40
# 492/493 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9226 - loss: 0.2210
# Epoch 12: val_loss did not improve from 0.80666
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9226 - loss: 0.2210 - val_accuracy: 0.6875 - val_loss: 0.9734
# Epoch 13/40
# 491/493 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9237 - loss: 0.2155
# Epoch 13: val_loss did not improve from 0.80666
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9237 - loss: 0.2155 - val_accuracy: 0.7354 - val_loss: 0.8757
# Epoch 14/40
# 490/493 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9283 - loss: 0.2096
# Epoch 14: val_loss improved from 0.80666 to 0.76516, saving model to best_model.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9283 - loss: 0.2096 - val_accuracy: 0.7577 - val_loss: 0.7652
# Epoch 15/40
# 490/493 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9302 - loss: 0.2024
# Epoch 15: val_loss improved from 0.76516 to 0.68597, saving model to best_model.keras
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.9302 - loss: 0.2024 - val_accuracy: 0.8013 - val_loss: 0.6860
# Epoch 16/40
# 491/493 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9352 - loss: 0.1915
# Epoch 16: val_loss did not improve from 0.68597
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9352 - loss: 0.1915 - val_accuracy: 0.7601 - val_loss: 0.7420
# Epoch 17/40
# 491/493 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9317 - loss: 0.1950
# Epoch 17: val_loss did not improve from 0.68597
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9317 - loss: 0.1950 - val_accuracy: 0.7792 - val_loss: 0.6902
# Epoch 18/40
# 491/493 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9370 - loss: 0.1806
# Epoch 18: val_loss did not improve from 0.68597
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9370 - loss: 0.1806 - val_accuracy: 0.7066 - val_loss: 0.8307
# Epoch 19/40
# 492/493 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9391 - loss: 0.1722
# Epoch 19: val_loss did not improve from 0.68597
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9391 - loss: 0.1722 - val_accuracy: 0.7588 - val_loss: 0.7686
# Epoch 20/40
# 492/493 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9394 - loss: 0.1719
# Epoch 20: val_loss did not improve from 0.68597
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9394 - loss: 0.1719 - val_accuracy: 0.7834 - val_loss: 0.6875
# Epoch 20: early stopping

# %%
import matplotlib.pyplot as plt

hist_4.history.keys()
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(hist_4.history['loss'],'b--',label='loss')
plt.plot(hist_4.history['val_loss'],'r',label='val_loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend()

plt.subplot(1,2,2)
plt.plot(hist_4.history['accuracy'],'b--',label='accuracy')
plt.plot(hist_4.history['val_accuracy'],'r',label='val_accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend()
plt.show()

# %%
model_4.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9176 - loss: 0.2742
# [0.2740364372730255, 0.920199990272522]
