# %% [markdown]
# ## 프롬프트 엔지니어링
#
# 정의
# - Prompt engineering은 인공지능 모델, 특히 언어 모델에게 특정 작업을 수행하도록 지시하는 명령어(prompt)를 설계하고 조정하는 기술입니다.
# - 사용자는 명확하고 구체적인 질문이나 지시를 통해 모델이 원하는 결과를 생성하도록 유도할 수 있습니다. 이 과정은 자연어 처리에서 중요한 역할을 하며, 모델의 출력을 최적화하고 정확도를 높이는 데 기여합니다.
#
# 활용 분야
# - ChatGPT와 같은 대화형 AI, 자동화된 글쓰기, 고객 서비스, 교육, 코드 생성, 의료 데이터 분석 등 다양한 분야에서 prompt engineering이 활용됩니다.
# - 이를 통해 AI가 특정 요구 사항에 맞춘 결과를 생성하도록 하여, 작업 효율성을 높이고 사용자 경험을 향상시킬 수 있습니다.
#
# 사례들은 대규모 언어 모델(LLM)을 활용하는 다양한 방법을 보여줍니다. 각 사례는 특정 작업에 맞게 프롬프트를 설계하여 모델이 어떻게 유용한 결과를 생성하는지 설명합니다.
#
# - 텍스트 생성: 창의적인 글쓰기, 마케팅 카피 작성, 기술 문서 생성 등 다양한 분야에서 사용됩니다. 프롬프트의 구체성과 맥락 설정에 따라 생성되는 텍스트의 품질이 달라집니다.
#
# - 코드 생성 및 보완: 개발자가 원하는 코드 스니펫을 생성하거나 오류를 수정하는 데 도움을 줍니다. 예를 들어, 특정 함수나 알고리즘을 구현할 때 LLM을 활용해 코드를 제안받을 수 있습니다.
#
# - 데이터 분석 및 요약: 대량의 데이터를 요약하거나 분석 결과를 해석하는 데 유용합니다. LLM을 통해 데이터를 자연어로 쉽게 설명할 수 있어, 비전문가도 결과를 이해하기 쉽게 만듭니다.
#
# - 교육 및 학습 지원: 특정 주제에 대한 설명을 제공하거나, 학습 문제를 풀 때 힌트를 제시하는 방식으로 활용됩니다. 이는 교육용 도구나 학습 지원 시스템에서 유용하게 쓰일 수 있습니다.
#
# - 대화형 응용: 고객 서비스, 개인 비서 역할을 하는 챗봇 등에서 LLM이 활용됩니다. 사용자의 질문에 대해 신속하고 정확한 답변을 제공하며, 자연스러운 대화를 통해 사용자 경험을 향상시킵니다.
#
# - 창의적 작업 지원: 예술적 작업이나 새로운 아이디어를 생성할 때, 예를 들어 스토리라인 생성이나 음악 작곡 등에서 창의성을 발휘할 수 있도록 LLM이 도와줍니다.

# %% [markdown]
# ## 더 나은 결과를 얻기 위한 프롬프트 6가지 전략
# 대규모 언어 모델(때로는 GPT 모델이라고도 함)에서 더 나은 결과를 얻기 위한 프롬프트 전략과 전술. 여기에 설명된 방법은 더 큰 효과를 위해 때때로 조합하여 사용
#
# 명확하고 구체적인 언어 사용
# - 모호한 표현 대신 구체적 단어 사용: 일반적 표현보다 구체적인 단어를 사용하여 명확히 전달합니다. 예: "빠르다" 대신 "5분 내에".
# - 명확한 문장 구조 유지: 단문을 사용하여 문장이 복잡하지 않도록 합니다.
#
# 단계별 지침 제공
# - 작업 분할: 작업을 여러 단계로 나누어 각 단계를 명확히 설명합니다.
# - 단계별 결과 명시: 각 단계에서 기대되는 결과를 구체적으로 작성합니다.
#
# 필요한 컨텍스트 제공
# - 관련 배경 정보 포함: 작업을 이해하는 데 필요한 배경 정보를 제공합니다.
# - 구체적 시간/상황 명시: 언제 또는 어떤 상황에서 작업이 수행되는지 명시합니다.
#
# 예시 제공
# - 긍정적/부정적 예시 포함: 올바른 예시와 잘못된 예시를 모두 제공하여 비교할 수 있게 합니다.
# - 다양한 시나리오 제시: 다양한 상황에 대한 예시를 포함합니다.
#
# 부가 정보 제공
# - 추가 리소스 링크 제공: 참고할 수 있는 추가 자료나 링크를 제공합니다.
# - 참조 자료 목록화: 관련 자료들을 목록으로 정리하여 쉽게 접근할 수 있게 합니다.
#
# 피드백 및 조정
# - 피드백 요청: 지침의 명확성을 확인하기 위해 사용자로부터 피드백을 요청합니다.
# - 지침 조정: 받은 피드백을 반영하여 지침을 수정하고 개선합니다.

# %% [markdown]
# **명확하고 구체적인 언어 사용**
#
# 모호한 표현 대신 구체적 단어 사용
# - 모호한 표현: "빠르게 제출하세요."
# - 구체적 표현: "5분 내에 제출하세요."
#
# 모호한 표현인 "빠르게"는 사람마다 다르게 해석될 수 있습니다. 어떤 사람에게는 "빠르게"가 1시간을 의미할 수도 있고, 다른 사람에게는 몇 분을 의미할 수도 있습니다. 반면 "5분 내에"는 정확한 시간을 명시하여 모두가 같은 의미로 이해할 수 있게 합니다. 이를 통해 지침의 명확성이 높아져 오해가 줄어들고, 작업이 더 정확하게 수행될 수 있습니다.
#
# **명확한 문장 구조 유지**
# - 복잡한 문장: "프로젝트 파일을 검토하고, 오류를 수정하며, 다음 회의 전에 팀원들과 공유하세요."
# - 단순한 문장: "프로젝트 파일을 검토하세요. 오류를 수정하세요. 다음 회의 전에 팀원들과 공유하세요."
#
# 복잡한 문장은 여러 작업을 한 문장에 포함하여 읽는 사람이 이해하기 어렵게 만듭니다. 단순한 문장은 각 작업을 별도의 문장으로 분리하여 각 지시사항을 명확하게 전달합니다. 이를 통해 독자는 각 작업의 순서와 중요성을 쉽게 파악할 수 있으며, 오해나 실수를 줄일 수 있습니다.
#
# **작업 분할**
# - 복잡한 작업 지시: "보고서를 작성하고 검토한 후, 이메일로 보내세요."
# - 단계별 작업 지시:<br>
#   - 보고서 작성:
#     - 관련 데이터를 수집하세요.
#     - 수집한 데이터를 분석하여 요약하세요.
#     - 분석 결과를 바탕으로 보고서를 작성하세요.
#   - 보고서 검토:
#     - 작성한 보고서를 읽고 오류를 수정하세요.
#     - 팀원에게 보고서를 공유하고 피드백을 받으세요.
#
#   - 이메일로 전송:
#     - 검토한 보고서를 이메일에 첨부하세요.
#     - 적절한 수신자에게 이메일을 보내세요.
#
# 작업을 여러 단계로 분할하면 각 단계의 구체적인 작업이 명확해집니다. 이를 통해 사용자는 각 단계를 하나씩 완료하면서 전체 작업을 체계적으로 수행할 수 있습니다. 작업 분할은 복잡한 작업을 관리 가능하고 이해하기 쉽게 만듭니다.
#
# **단계별 결과 명시**
# - 작업 지시: 보고서를 작성하고 검토한 후, 이메일로 보내세요.
# - 단계별 결과 명시:
#   - 보고서 작성:
#     - 결과: 초안 보고서 완성. 데이터가 정확히 포함되어 있음.
#   - 보고서 검토:
#     - 결과: 오류가 수정된 보고서. 피드백이 반영됨.
#   - 이메일로 전송:
#     - 결과: 보고서가 이메일에 첨부되어 적절한 수신자에게 전송됨.
#
# 각 단계에서 기대되는 결과를 구체적으로 명시하면 사용자가 작업의 목표를 명확히 이해할 수 있습니다. 이를 통해 단계별로 작업의 완성도를 확인할 수 있고, 최종 결과물이 기대에 부합하는지 확인할 수 있습니다. 단계별 결과 명시는 작업의 명확성과 효율성을 높이는 데 중요한 역할을 합니다.
#
# **관련 배경 정보 포함**
# - 지시사항: "지난 주의 프로젝트 파일을 검토하세요."
# - 관련 배경 정보 포함:
#   - 프로젝트 개요:
#     - 배경 정보: "이 프로젝트는 고객 만족도 향상을 목표로 합니다. 지난 주 회의에서 고객 피드백을 분석하고, 이를 반영한 새로운 전략을 논의했습니다."
#   - 특정 파일 지시:
#     - 배경 정보: "지난 주에 작성된 '고객 피드백 분석 보고서'와 '전략 수정 제안서' 파일을 검토하세요. 이 파일들은 프로젝트 폴더의 '2024년 8월' 섹션에 있습니다."
#   - 검토 목적:
#     - 배경 정보: "이번 검토는 제안된 전략이 효과적인지 평가하고, 추가 개선 사항을 도출하는 것을 목표로 합니다."
#
# 작업을 이해하는 데 필요한 배경 정보를 제공하면 사용자가 작업의 목적과 맥락을 명확히 이해할 수 있습니다. 이로 인해 작업 수행의 정확성과 효율성이 높아집니다. 배경 정보는 작업의 중요성, 관련 문서 위치, 수행해야 할 구체적 내용 등을 포함할 수 있습니다.
#
# **구체적 시간/상황 명시**
# - 모호한 지시사항: "회의 전에 보고서를 작성하세요."
# - 구체적 지시사항:
#   - 시간 명시:
#     - 구체적 표현: "월요일 오전 9시 회의 전에 보고서를 작성하세요."
#     - 상황: "회의는 매주 월요일 오전 9시에 시작됩니다. 이 회의에서 이번 주 목표와 작업 분담이 논의될 예정입니다."
#   - 상황 명시:
#     - 구체적 표현: "월간 실적 검토 회의 전에, 이번 달 매출 보고서를 작성하세요."
#     - 상황: "월간 실적 검토 회의는 매월 마지막 금요일 오후 3시에 열립니다. 이 보고서는 전체 팀의 실적을 평가하는 데 사용됩니다."
#
# 구체적인 시간과 상황을 명시하면 작업의 시기와 맥락을 명확히 할 수 있습니다. 이는 사용자가 언제 작업을 완료해야 하는지 정확히 이해하게 하여, 일정 준수와 작업의 적시 수행을 도와줍니다. 또한, 작업의 중요성과 맥락을 이해함으로써, 더 나은 준비와 수행이 가능해집니다.
#
# **긍정적/부정적 예시 포함**
# - 지시사항: "이메일을 작성하세요."
# - 긍정적 예시:
#   - 제목: "회의 일정 확인 요청"
#   - 내용: "안녕하세요, 김 팀장님. 이번 주 금요일 오후 2시에 예정된 회의 일정을 확인하고자 합니다. 참석 가능하신지 알려주시면 감사하겠습니다. 감사합니다. 홍길동 드림."
# - 부정적 예시:
#   - 제목: "회의"
#   - 내용: "안녕하세요, 회의가 이번 주 금요일에 있을 것 같습니다. 참석할 수 있는지 알려주세요. 홍길동."
#
# 긍정적 예시와 부정적 예시를 제공하면 사용자는 무엇이 올바르고 무엇이 잘못된지 명확히 이해할 수 있습니다. 긍정적 예시는 최상의 결과를 보여주어 기대하는 바를 명확히 전달하며, 부정적 예시는 피해야 할 실수를 구체적으로 보여줍니다. 이를 통해 사용자는 지침을 더 잘 따르고, 결과물의 품질을 높일 수 있습니다.
#
# **다양한 시나리오 제시**
# - 지시사항: "보고서를 작성하세요."
# - 다양한 시나리오:
#   - 주간 보고서 작성:
#     - 상황: 매주 금요일마다 주간 업무 요약 보고서를 작성합니다.
#     - 포함 내용: 주요 성과, 문제점, 다음 주 계획.
#     - 긍정적 예시: "이번 주 주요 성과로는 판매 목표 120% 달성이 있습니다. - 문제점으로는 재고 부족이 있었으며, 이를 해결하기 위해 다음 주에는 재고 보충 계획을 세웠습니다."
#     - 부정적 예시: "이번 주에 여러 가지 일이 있었고, 다음 주에도 할 일이 많습니다."
#   - 프로젝트 보고서 작성:
#     - 상황: 프로젝트 마감 시 프로젝트 진행 상황과 결과를 요약한 보고서를 작성합니다.
#     - 포함 내용: 프로젝트 목표, 진행 상황, 최종 결과, 배운 점.
#     - 긍정적 예시: "프로젝트 목표는 고객 만족도 향상이었고, 진행 상황은 계획대로 진행되었습니다. 최종 결과로 고객 만족도가 20% 향상되었습니다. 배운 점은 초기 계획의 중요성입니다."
#     - 부정적 예시: "프로젝트가 끝났고, 결과가 나왔습니다."
#   - 연구 보고서 작성:
#     - 상황: 연구 프로젝트의 결과를 발표하기 위한 보고서를 작성합니다.
#     - 포함 내용: 연구 목적, 방법, 결과, 결론.
#     - 긍정적 예시: "연구 목적은 새로운 항생제의 효과를 검증하는 것이었습니다. 실험 방법은 무작위 대조 실험이었고, 결과는 긍정적이었습니다. 결론은 새로운 항생제가 효과적이라는 것입니다."
#     - 부정적 예시: "연구를 했고, 결과가 좋았습니다."
#
# 다양한 시나리오를 제시하면 사용자는 각 상황에 맞게 작업을 어떻게 수행해야 하는지 명확히 이해할 수 있습니다. 각 시나리오의 구체적인 예시를 통해, 사용자는 자신이 직면한 상황에 적합한 지침을 적용할 수 있으며, 기대되는 결과물의 기준을 명확히 알 수 있습니다.
#
# **추가 리소스 링크 제공 및 참조 자료 목록화**
# - 지시사항: "보고서를 작성하기 위한 참고 자료를 확인하세요."
# - 추가 리소스 링크 제공:
#   - 링크 1: 보고서 작성 가이드라인
#   - 링크 2: 데이터 분석 기법
#   - 링크 3: 피드백 수집 방법
# - 참조 자료 목록화:
#   - 보고서 작성 가이드라인:
#     - 내용: 보고서의 구조, 형식, 필수 요소에 대한 상세 지침
#     - 링크: 보고서 작성 가이드라인
#   - 데이터 분석 기법:
#     - 내용: 데이터를 효과적으로 분석하는 방법과 도구
#     - 링크: 데이터 분석 기법
#   - 피드백 수집 방법:
#     - 내용: 피드백을 효과적으로 수집하고 활용하는 방법
#     - 링크: 피드백 수집 방법
#
# 추가 리소스 링크를 제공하면 사용자는 필요한 정보를 쉽게 찾아볼 수 있습니다. 참조 자료를 목록화하면 관련 자료를 체계적으로 정리하여 사용자가 필요할 때 빠르게 접근할 수 있게 도와줍니다. 이는 작업의 정확성과 효율성을 높이는 데 매우 유용합니다.
#
# **피드백 요청**
# - 지시사항: "보고서를 작성한 후, 제출하세요."
# - 피드백 요청 추가:
#   - 초안 제출:
#     - 지시사항: "보고서 초안을 작성한 후, 팀원들에게 공유하세요."
#     - 피드백 요청: "초안에 대한 피드백을 받으세요. 피드백을 바탕으로 수정 사항을 반영하세요."
#   - 최종본 제출:
#     - 지시사항: "피드백을 반영한 최종 보고서를 작성한 후, 제출하세요."
#     - 피드백 요청: "제출 전, 팀원 또는 관리자에게 최종 확인을 요청하세요. 보고서의 명확성과 완성도를 높이기 위해 피드백을 활용하세요."
#
# 피드백 요청을 통해 지침의 명확성을 확인하고 개선할 수 있습니다. 사용자로부터 피드백을 받으면, 지침이 제대로 이해되고 있는지 확인할 수 있으며, 필요한 경우 수정하여 더 명확하고 효과적인 지침을 제공할 수 있습니다. 이를 통해 작업의 품질과 정확성을 높일 수 있습니다.
#
# **지침 조정**
# - 초기 지침:
# "프로젝트 계획서를 작성하세요."
# - 피드백:
#   - "계획서에 포함해야 할 세부 항목이 명확하지 않습니다."
#   - "완료 기한이 명시되지 않아 혼란스럽습니다."
# - 수정된 지침:
#   - 프로젝트 계획서 작성:
#     - 포함 항목:
#       - 프로젝트 개요
#       - 목표 및 기대 성과
#       - 주요 단계 및 일정
#       - 필요한 자원
#     - 완료 기한:
#       - "다음 주 금요일 오후 5시까지 제출하세요."
#
# 피드백을 반영하여 지침을 수정하면, 지침의 명확성과 효과성이 개선됩니다. 사용자가 작업을 더 정확하고 효율적으로 수행할 수 있도록 도와줍니다. 피드백을 통해 지침의 문제점을 파악하고, 구체적이고 명확한 지침으로 수정하는 과정이 중요합니다.

# %%
# !pip install -q openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.3/361.3 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.7 MB/s eta 0:00:00

# %% [markdown]
# Chat Completion

# %%
from openai import OpenAI
client = OpenAI(api_key='')

completion = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
    {"role": "system", "content": "당신은 AI 모델 개발자이다."},
    {"role": "user", "content": "LLM에 대해 설명해줘"}
  ]
)

# print(completion)
print(completion.choices[0].message.content)
# Out:
# LLM은 "Large Language Model"의 약자로, 대규모 언어 모델을 의미합니다. LLM은 대량의 텍스트 데이터를 기반으로 훈련되어 자연어 처리(NLP) 작업을 수행할 수 있는 인공지능 모델입니다. 이 모델은 주어진 입력 텍스트에 대해 적절한 응답을 생성하거나, 텍스트를 이해하고 분석하는 데 사용됩니다.
#
# LLM의 주요 특징은 다음과 같습니다:
#
# 1. **대규모 데이터 학습**: LLM은 수백억 단어 이상의 텍스트 데이터로 훈련됩니다. 이 데이터를 통해 언어의 문법, 의미, 문맥 등을 이해하게 됩니다.
#
# 2. **트랜스포머 아키텍처**: 많은 LLM은 트랜스포머라는 신경망 아키텍처를 기반으로 합니다. 트랜스포머는 효율적인 병렬 처리가 가능하고 긴 의존성을 학습하는 데 강력한 성능을 보여줍니다.
#
# 3. **다양한 작업 수행**: LLM은 텍스트 생성, 번역, 요약, 질문 답변, 감정 분석 등 다양한 언어 처리 작업을 수행할 수 있습니다.
#
# 4. **컨텍스트 이해**: LLM은 입력된 텍스트의 문맥을 이해하고, 관련된 정보를 기반으로 응답할 수 있는 능력을 가지고 있습니다. 이를 통해 더욱 자연스러운 대화가 가능합니다.
#
# 5. **파인튜닝**: LLM은 특정 작업이나 도메인에 맞게 추가로 훈련(파인튜닝)할 수 있어, 특정 응용 프로그램에 최적화된 성능을 발휘할 수 있습니다.
#
# 6. **비판과 한계**: LLM은 때때로 잘못된 정보를 생성하거나 편향된 결과를 출력할 수 있으며, 이러한 문제는 사용 시 주의가 필요합니다.
#
# LLM은 최근 인공지능 발전의 중요한 주제로, 다양한 분야에서 활용되고 있습니다.

# %% [markdown]
# 명확성과 구체성
#
# - 특정 주제에 대해 글을 작성하도록 요청할 때

# %%
from openai import OpenAI

# 명확하고 구체적인 프롬프트
prompt = '재생 가능 에너지원이 지구 온난화를 줄이는데 기여하는 이점에 대해 간결한 단락으로 설명해 주세요'

completion = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
    {"role": "system", "content": "당신은 환경문제를 연구하는 과학자이다."},
    {"role": "user", "content": prompt}
  ]
)

print(completion.choices[0].message.content)
# Out:
# 재생 가능 에너지원, 예를 들어 태양광, 풍력, 수력 및 바이오매스는 지구 온난화를 줄이는 데 중요한 역할을 합니다. 이들 에너지원은 화석 연료에 비해 이산화탄소 및 기타 온실가스를 거의 배출하지 않으며, 따라서 대기 중 온실가스 농도를 줄이는 데 기여합니다. 또한, 지속 가능한 에너지 생산 방식은 자연 자원의 고갈을 최소화하고 생태계의 건강을 유지하는 데 도움이 됩니다. 이러한 이유로 재생 가능 에너지원은 기후 변화 대응의 핵심 요소로 자리 잡고 있습니다.

# %%
from openai import OpenAI

prompt = '최근의 우주 탐사 미션이 인류의 우주 이해에 어떻게 기여하고 있는지에 대해 간결한 단락으로 설명해 주세요.'

completion = client.chat.completions.create(
    model = 'gpt-4o-mini',
    messages = [
        {'role': 'system', 'content': '당신은 우주를 연구하는 과학자이다.'},
        {'role': 'user', 'content': prompt}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 최근의 우주 탐사 미션은 인류의 우주 이해를 획기적으로 확대하고 있습니다. 예를 들어, 제임스 웹 우주 망원경(JWST)은 고대 우주와 별의 형성 과정을 관찰하여 우주의 초기 역사에 대한 통찰을 제공하며, 화성 탐사선들은 이 행성의 기후와 지질학적 특성을 연구함으로써 생명 가능성에 대한 새로운 데이터를 수집하고 있습니다. 이러한 미션들은 우주 물리학, 천체 생물학 및 행성 과학 분야에서의 지식을 향상시키고, 인류가 우주에서의 위치와 존재 의의를 이해하는 데 중요한 기초를 마련하고 있습니다.

# %% [markdown]
# 맥락 제공
# - 특정 사건에 대한 설명을 요청할 때

# %%
prompt = (
    '다음 맥락을 고려하여 설명해 주세요: 2020년, 전 세계적인 펜데믹은 다양한 산업에 큰 혼란을 초래했습니다'
    '글로벌 공급망에 미친 영행을 분석해 주세요'
)

completion = client.chat.completions.create(
    model = 'gpt-4o-mini',
    messages = [
        {'role': 'system', 'content': '당신은 경제전문가이다'},
        {'role': 'user', 'content': prompt}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 2020년 COVID-19 팬데믹은 전 세계적으로 거의 모든 산업에 지대한 영향을 미쳤으며, 특히 글로벌 공급망에 미친 영향은 심각하고 광범위했습니다. 다음은 이러한 영향을 분석한 내용입니다.
#
# ### 1. 공급망의 중단
# 팬데믹으로 인해 여러 국가가 봉쇄 조치를 시행하면서 생산 시설, 물류, 및 운송이 중단되었습니다. 이는 부품과 원자재의 공급 부족으로 이어졌고, 특히 중국과 같은 주요 제조국에서의 생산 감소가 전 세계 시장에 큰 영향을 미쳤습니다.
#
# ### 2. 수요의 급격한 변화
# 소비자 행동이 변화하면서 특정 산업은 수요 증가를 경험했고, 다른 산업은 급격한 수요 감소를 겪었습니다. 예를 들어, 의료 용품과 식품 관련 산업은 급증한 수요로 인해 공급망 어려움을 겪었고, 항공여행 및 관광 산업은 극심한 타격을 받았습니다.
#
# ### 3. 물류 및 운송의 문제
# 국제 운송이 제한되면서 화물 운송의 비용이 급증하고, 항만과 물류센터의 병목 현상이 발생했습니다. 배달 지연과 물류비용 상승이 잦아지며, 기업들은 고객의 기대를 충족시키기 어려워졌습니다.
#
# ### 4. 디지털 전환 가속화
# 많은 기업들이 팬데믹 상황에서 디지털화를 가속화하였습니다. 이를 통해 일부 기업은 온라인 판매와 비대면 고객 서비스를 강화하며 공급망 관리의 효율성을 높일 수 있었습니다. 하지만, 디지털화가 급격히 이루어진 만큼, 사이버 보안과 데이터 보호의 중요성도 커졌습니다.
#
# ### 5. 공급망의 다변화
# 많은 기업들이 단일 국가 의존도를 줄이고 다양한 지역에서의 공급망 구축을 고려하게 되었습니다. 이는 공급망의 복원력을 높이기 위해 지역 생산지 확대와 다국적 생산 전략을 모색하도록 유도했습니다.
#
# ### 6. 재고 관리의 변화
# 팬데믹 초기에는 재고가 부족해지자 기업들은 ‘적시 생산(JIT)’ 시스템의 한계를 경험했습니다. 이에 따라 많은 기업들은 재고 관리를 강화하고, 안정적인 공급망 운영을 위한 전략을 재고하게 되었습니다.
#
# ### 결론
# 2020년 팬데믹은 글로벌 공급망에서의 유연성과 복원력의 중요성을 드러냈으며, 기업들은 앞으로의 불확실성에 대비하기 위해 공급망 전략을 재조정해야 하는 상황에 직면하게 되었습니다. 이러한 변화는 공급망 관리의 패러다임을 새롭게 정의할 것으로 예상됩니다.

# %% [markdown]
# 반복과 테스트
# - 여러 프롬프트를 테스트하여 최적의 결과 도축

# %%
prompts = [
    '정기적인 운동의 건강상의 이점은 무엇인가요?',
    '정기적인 운동을 하는 것의 장점을 설명해 주세요',
    '정기적인 신체 활동이 건강에 어떤 영향을 미치나요?'
]
for prompt in prompts:
    completion = client.chat.completions.create(
        model = 'gpt-4o-mini',
        messages = [
            {'role': 'system', 'content': '당신은 건강관리 전문가이다.'},
            {'role': 'user', 'content': prompt}
        ]
    )
    print(f'프롬프트: {prompt}')
    print(completion.choices[0].message.content)
    print('\n' + '='*100 + '\n')
# Out:
# 프롬프트: 정기적인 운동의 건강상의 이점은 무엇인가요?
# 정기적인 운동은 여러 가지 건강상의 이점을 제공합니다. 주요한 이점은 다음과 같습니다:
#
# 1. **심혈관 건강 증진**: 운동은 심장 기능을 향상시키고, 혈압을 낮추며, 콜레스테롤 수치를 개선하여 심혈관 질환의 위험을 줄입니다.
#
# 2. **체중 관리**: 규칙적인 신체 활동은 칼로리를 소모하고 체중을 조절하는 데 도움을 줍니다. 비만 및 관련 질병의 위험을 낮출 수 있습니다.
#
# 3. **근육 및 뼈의 강화**: 운동은 근육을 강화하고 뼈 밀도를 증가시켜 골다공증 등의 질병 예방에 기여합니다.
#
# 4. **정신 건강 개선**: 운동은 스트레스, 불안 및 우울증 증상을 완화하는 데 도움을 줄 수 있습니다. 엔도르핀과 같은 기분 개선 호르몬이 분비됩니다.
#
# 5. **면역력 강화**: 규칙적인 운동은 면역 시스템을 강화하여 감염에 대한 저항력을 높일 수 있습니다.
#
# 6. **정신적 집중력 향상**: 운동은 집중력과 기억력을 개선하고, 뇌 건강에 긍정적인 영향을 미칩니다.
#
# 7. **수면 개선**: 규칙적인 신체 활동은 수면 질을 향상시키고 불면증의 증상을 줄이는 데 도움이 됩니다.
#
# 8. **아름다운 피부**: 운동은 혈액 순환을 개선하여 피부 건강에도 긍정적인 영향을 미칩니다.
#
# 9. **장 건강 증진**: 운동은 소화 과정을 개선하고 장의 건강을 유지하는 데 도움을 줄 수 있습니다.
#
# 10. **전반적인 삶의 질 향상**: 신체 활동은 에너지를 증가시키고, 사회적 상호작용을 촉진하여 전반적인 삶의 질을 높입니다.
#
# 이러한 이점들은 꾸준한 운동을 통해 얻을 수 있으며, 개인의 건강 상태와 목표에 따라 다양한 형태의 운동을 선택할 수 있습니다.
#
# ====================================================================================================
#
# 프롬프트: 정기적인 운동을 하는 것의 장점을 설명해 주세요
# 정기적인 운동은 신체적, 정신적, 정서적 건강에 많은 장점이 있습니다. 아래에 몇 가지 주요 장점을 설명해 드리겠습니다:
#
# 1. **신체 건강 증진**: 운동은 심장과 폐의 기능을 개선하고, 근육과 뼈를 강화하여 전반적인 신체 건강을 증진시킵니다. 또한 체중 관리에 도움이 되고, 비만 예방 및 치료에 효과적입니다.
#
# 2. **심혈관 건강**: 정기적인 유산소 운동은 혈압을 낮추고, 심장 질환의 위험을 줄여줍니다. 혈중 콜레스테롤 수치를 개선하여 건강한 혈관을 유지하는 데 기여합니다.
#
# 3. **정신적 건강 개선**: 운동은 스트레스를 줄이고, 불안을 완화하며, 우울증 증상을 개선하는 데 도움을 줍니다. 운동 중에는 엔도르핀과 같은 기분이 좋게 만드는 화학물질이 분비됩니다.
#
# 4. **수면 질 향상**: 규칙적인 신체 활동은 수면의 질을 향상시킬 수 있으며, 불면증이나 기타 수면 장애를 완화하는 데 도움이 됩니다.
#
# 5. **면역력 강화**: 운동은 면역 체계를 강화하여 감염 및 질병에 대한 저항력을 높이는 데 도움을 줄 수 있습니다.
#
# 6. **인지 기능 향상**: 연령이 들면서 인지 기능이 저하될 수 있지만, 운동은 뇌의 혈류를 증가시키고, 기억력 및 집중력을 향상시키는 데 도움이 됩니다.
#
# 7. **사회적 상호작용**: 운동은 친구 및 가족과의 상호작용 기회를 제공하여 사회적 관계를 강화하고, 대인관계를 개선하는 데 도움을 줍니다.
#
# 8. **자신감 향상**: 운동을 통해 신체적 변화와 성취감을 경험하게 되면, 자신감이 향상되고 자존감이 높아질 수 있습니다.
#
# 9. **장기적인 건강 유지**: 정기적인 운동은 만성 질환의 위험을 줄이고, 건강한 수명을 증가시키는 데 기여합니다.
#
# 이러한 장점들을 통해 정기적인 운동은 전반적인 웰빙과 삶의 질 향상에 매우 중요한 역할을 하게 됩니다.
#
# ====================================================================================================
#
# 프롬프트: 정기적인 신체 활동이 건강에 어떤 영향을 미치나요?
# 정기적인 신체 활동은 건강에 여러 가지 긍정적인 영향을 미칩니다. 그 중 몇 가지를 살펴보면:
#
# 1. **심혈관 건강 개선**: 규칙적인 운동은 심장의 기능을 향상시키고, 혈압을 낮추며, 혈액 순환을 원활하게 합니다. 이는 심혈관 질환의 위험을 줄이는 데 도움을 줍니다.
#
# 2. **체중 관리**: 신체 활동은 칼로리를 소모하고 신진대사를 촉진하여 체중 조절에 효과적입니다. 비만 예방 및 치료에 중요한 역할을 합니다.
#
# 3. **근육과 뼈 건강**: 운동은 근육을 강화하고 뼈의 밀도를 증가시켜 노화와 관련된 골다공증 등의 질환 예방에 기여합니다.
#
# 4. **정신 건강 증진**: 신체 활동은 스트레스 감소, 우울증과 불안 완화, 그리고 자존감 향상에 도움을 주는 것으로 알려져 있습니다. 운동 중 분비되는 엔도르핀은 기분을 좋게 하는 효과가 있습니다.
#
# 5. **면역 체계 강화**: 규칙적인 운동은 면역 시스템을 강화하여 감염으로부터의 저항력을 높이는 데 기여할 수 있습니다.
#
# 6. **수면 개선**: 운동은 수면의 질을 향상시키고, 더 깊고 편안한 수면을 유도하는 데 도움을 줄 수 있습니다.
#
# 7. **전반적인 삶의 질 향상**: 신체 활동은 에너지를 증가시키고, 일상 생활의 활력을 높이며, 사회적 상호작용을 촉진해 전반적인 삶의 질을 향상시킵니다.
#
# 이러한 이유로, 전문가들은 적어도 주 150분 이상의 중간 강도 운동(예: 걷기, 자전거 타기)을 권장합니다. 그러나 운동은 개인의 상태와 목표에 따라 조절해야 하므로, 자신의 몸에 맞는 방법을 찾는 것이 중요합니다.
#
# ====================================================================================================

# %% [markdown]
# 예시 사용
# - 특정 형식의 응답을 요청할 때

# %%
from openai import OpenAI

prompt = (
    '숫자의 팩토리얼을 계산하는 파이썬 함수를 작성해 주세요.'
    '예시:\n'
    '입력:5\n'
    '출력:120\n'
    '함수 코드:'
)

completion = client.chat.completions.create(
    model='gpt-4o-mini',
    messages=[
        {'role': 'system', 'content': '당신은 파이썬 코딩을 가르치는 코딩 튜터이다.'},
        {'role': 'user', 'content': prompt}
    ]
)
print(completion.choices[0].message.content)
# Out:
# 숫자의 팩토리얼을 계산하는 파이썬 함수를 작성해 보겠습니다. 팩토리얼은 주어진 숫자 \( n \)에 대해 \( n! = n \times (n - 1) \times (n - 2) \times \ldots \times 1 \)로 정의됩니다. \( 0! \)의 값은 1로 정의됩니다.
#
# 다음은 해당 기능을 구현한 파이썬 함수입니다:
#
# ```python
# def factorial(n):
#     if n < 0:
#         return "음수의 팩토리얼은 정의되지 않습니다."
#     elif n == 0 or n == 1:
#         return 1
#     else:
#         result = 1
#         for i in range(2, n + 1):
#             result *= i
#         return result
#
# # 예시 사용
# print(factorial(5))  # 출력: 120
# ```
#
# 이 함수는 다음과 같이 작동합니다:
# - `n`이 0 또는 1일 경우, 1을 반환합니다 (0!와 1!은 1입니다).
# - `n`이 0보다 작으면, 음수의 팩토리얼은 정의되지 않기 때문에 에러 메시지를 반환합니다.
# - 그 외의 경우에는 2부터 \( n \)까지의 모든 정수를 곱하여 결과를 반환합니다.

# %% [markdown]
# 지시관리
# - 응답 형식과 길이를 명확히 지시

# %%
# prompt = """다음 텍스트의 주요 포인트를 50자 이내로 요야해주세요:
prompt = """다음 텍스트의 주요 포인트를 1000자 이내로 요약해 주세요:
인공지는(AI)은 다양한 산업에서 급속히 성장하는 분야로, 업무 자동화, 데이터 분석을 통한 인사이트 제공,
개인 맞춤형 추천을 통한 고객 경험 향상등의 응용 분야가 있습니다."""

completion = client.chat.completions.create(
    model='gpt-4o-mini',
    messages=[
        {'role': 'system', 'content': '당신은 인공지능을 학습하는 대학원생이다.'},
        {'role': 'user', 'content': prompt}
    ]
)
print(completion.choices[0].message.content)
# Out:
# 인공지능(AI)은 다양한 산업에서 빠른 성장세를 보이며, 여러 가지 응용 분야를 가지고 있습니다. 주요 응용 분야로는 업무 자동화가 있으며, 이는 반복적인 작업을 효율적으로 수행하여 인적 자원과 시간을 절약할 수 있습니다. 또한, AI는 데이터 분석을 통해 인사이트를 제공함으로써 기업들이 더 나은 의사결정을 내릴 수 있도록 지원합니다. 개인 맞춤형 추천 시스템도 중요한 역할을 하며, 고객의 행동과 선호를 분석하여 개인에게 최적화된 경험을 제공합니다. 이러한 AI의 다양한 활용은 기업 경쟁력을 높이고, 고객 만족을 증대시키는 데 기여하고 있습니다. AI는 앞으로도 더욱 발전하며 산업 전반에 걸쳐 큰 영향을 미칠 것으로 기대됩니다.

# %% [markdown]
# 문법 교정

# %%
response = client.chat.completions.create(
    model = 'gpt-4o-mini',
    messages=[
        {'role': 'system',
         'content': 'You will be brovided with statements, and your task is to convert them to standard English.'},
        {'role': 'user',
        'content': 'She no went to the market.'
        }
    ],
    temperature = 0.1,
    max_tokens=64,
    top_p=1
)

print(response.choices[0].message.content)
# Out:
# She didn't go to the market.

# %%
response = client.chat.completions.create(
    model = 'gpt-4o-mini',
    messages=[
        {'role': 'system',
         'content': '당신은 한국어 교사야. 문법적으로 틀린 표현을 수정해줘'},
        {'role': 'user',
        'content': '나는 간다 학교에.'
        }
    ],
    temperature = 0.1,
    max_tokens=64,
    top_p=1
)

print(response.choices[0].message.content)
# Out:
# "나는 학교에 간다."로 수정하면 됩니다.

# %% [markdown]
# 구조화 되지 않은 텍스트로부터 표를 만듭니다

# %%
prompt = """
최근에 발견된 행성 구크룩스에서 발견된 과일이 많이 있습니다. 거기에는 보라색이고 사탕 맛이 나는 네오스키즐이 자랍니다.
또한 칙칙한 파란색 과일인 로헤클도 있는데, 레몬과 비슷한 매우 신맛이 납니다. 포우닛은 밝은 녹색이고 단맛보다는 짭짤함이 더 강합니다.
네온 핑크 맛이며 솜사탕 맛이 나는 루프노바도 많이 있습니다. 마지막으로 글로울이라는 과일이 있는데,
매우 신맛이 나고 쓴맛이 나는 산성이고 부식성이 있으며 옅은 오렌지색을 띱니다.
"""

response = client.chat.completions.create(
    model = 'gpt-4o-mini',
    messages=[
        {'role': 'system',
         'content': '구조화 되지 않은 데이터가 제공되면 이를 CSV 형식으로 구문 분석하는 것이 여러분의 과제입니다'},
        {'role': 'user',
        'content': prompt
        }
    ],
    temperature = 0.7,
    max_tokens=300,
    top_p=1
)

print(response.choices[0].message.content)
# Out:
# 다음은 제공된 정보를 기반으로 한 CSV 형식의 데이터입니다.
#
# ```csv
# 과일 이름,색상,맛
# 네오스키즐,보라색,사탕 맛
# 로헤클,칙칙한 파란색,신맛
# 포우닛,밝은 녹색,짭짤함
# 루프노바,네온 핑크,솜사탕 맛
# 글로울,옅은 오렌지색,신맛 및 쓴맛
# ```
#
# 이 데이터는 각 과일에 대한 이름, 색상 및 맛을 포함하고 있습니다.
